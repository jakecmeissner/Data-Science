# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
police_shootings_df = pd.read_csv('/Users/jakemeissner/Desktop/datasets/police_shooting_data/fatal-police-shootings-data.csv')

# %%
police_shootings_df.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# ...

# %%
police_shootings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3464 entries, 0 to 3463
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       3464 non-null   int64
#  1   name                     3464 non-null   object
#  2   date                     3464 non-null   object
#  3   manner_of_death          3464 non-null   object
#  4   armed                    3458 non-null   object
#  5   age                      3334 non-null   float64
#  6   gender                   3459 non-null   object
#  7   race                     3170 non-null   object
#  8   city                     3464 non-null   object
#  9   state                    3464 non-null   object
#  10  signs_of_mental_illness  3464 non-null   bool
#  11  threat_level             3464 non-null   object
#  12  flee                     3349 non-null   object
#  13  body_camera              3464 non-null   bool
# ...

# %%
police_shootings_df.sort_values('date', ascending=False)[:3]
# Out:
#         id          name        date manner_of_death         armed   age  \
# 3463  3822         TK TK  2018-07-04            shot  undetermined   NaN
# 3462  3821    Ryan Force  2018-07-04            shot           gun  35.0
# 3461  3824  Frank Dripps  2018-07-03            shot           gun  52.0
#
#      gender race             city state  signs_of_mental_illness threat_level  \
# 3463      M  NaN           Pueblo    CO                    False       attack
# 3462      M  NaN  Spalding County    GA                     True       attack
# 3461      M  NaN      South Elgin    IL                    False       attack
#
#              flee  body_camera
# 3463          NaN        False
# 3462  Not fleeing         True
# 3461  Not fleeing        False

# %%
police_shootings_df.nunique()
# Out:
# id                         3464
# name                       3349
# date                       1193
# manner_of_death               2
# armed                        77
# age                          76
# gender                        2
# race                          6
# city                       1810
# state                        51
# signs_of_mental_illness       2
# threat_level                  3
# flee                          4
# body_camera                   2
# dtype: int64

# %%
# caffeine_df[caffeine_df['drink'].str.match('Maxwell')]
# police_shootings_df[police_shootings_df['race'].str.match('B')]

# %%
police_shootings_df['race'].unique()
# Out:
# array(['A', 'W', 'H', 'B', 'O', nan, 'N'], dtype=object)

# %%
police_shootings_df[police_shootings_df['race'] == 'B']
# Out:
#         id                              name        date manner_of_death  \
# 9       17                   Leslie Sapp III  2015-01-06            shot
# 11      21                         Ron Sneed  2015-01-07            shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed  2015-01-07            shot
# 14      27  Omarr Julian Maximillian Jackson  2015-01-07            shot
# 17      36               Artago Damon Howard  2015-01-08            shot
# ...    ...                               ...         ...             ...
# 3433  3788                  Jonathan Buckley  2018-06-19            shot
# 3434  3789                       Antwon Rose  2018-06-19            shot
# 3436  3792             Anthony Marcell Green  2018-06-20            shot
# 3440  3796                   Thurman Blevins  2018-06-23            shot
# 3441  3797            Detandel Pickens Devon  2018-06-23            shot
#
#            armed   age gender race            city state  \
# ...

# %%
police_shootings_df[police_shootings_df['race'] == 'B']['id'].nunique()
# Out:
# 818

# %%
police_shootings_df[police_shootings_df['race'] == 'W']['id'].nunique()
# Out:
# 1631

# %%
black_police_shooting_victims = police_shootings_df[police_shootings_df['race'] == 'B']
black_police_shooting_victims[:3]
# Out:
#     id                            name        date manner_of_death  \
# 9   17                 Leslie Sapp III  2015-01-06            shot
# 11  21                       Ron Sneed  2015-01-07            shot
# 12  22  Hashim Hanif Ibn Abdul-Rasheed  2015-01-07            shot
#
#          armed   age gender race       city state  signs_of_mental_illness  \
# 9   toy weapon  47.0      M    B  Knoxville    PA                    False
# 11         gun  31.0      M    B   Freeport    TX                    False
# 12       knife  41.0      M    B   Columbus    OH                     True
#
#    threat_level         flee  body_camera
# 9        attack  Not fleeing        False
# 11       attack  Not fleeing        False
# 12        other  Not fleeing        False

# %%
white_police_shooting_victims = police_shootings_df[police_shootings_df['race'] == 'W']
white_police_shooting_victims[:3]
# Out:
#    id               name        date manner_of_death       armed   age gender  \
# 1   4   Lewis Lee Lembke  2015-01-02            shot         gun  47.0      M
# 3   8    Matthew Hoffman  2015-01-04            shot  toy weapon  32.0      M
# 5  11  Kenneth Joe Brown  2015-01-04            shot         gun  18.0      M
#
#   race           city state  signs_of_mental_illness threat_level  \
# 1    W          Aloha    OR                    False       attack
# 3    W  San Francisco    CA                     True       attack
# 5    W        Guthrie    OK                    False       attack
#
#           flee  body_camera
# 1  Not fleeing        False
# 3  Not fleeing        False
# 5  Not fleeing        False

# %%
black_police_shooting_victims['age'].describe()
# Out:
# count    806.000000
# mean      32.171216
# std       11.064260
# min       13.000000
# 25%       24.000000
# 50%       30.000000
# 75%       38.000000
# max       77.000000
# Name: age, dtype: float64

# %%
white_police_shooting_victims['age'].describe()
# Out:
# count    1622.000000
# mean       39.833539
# std        13.270941
# min         6.000000
# 25%        30.000000
# 50%        38.000000
# 75%        49.000000
# max        91.000000
# Name: age, dtype: float64

# %%
sns.histplot(black_police_shooting_victims['age'])
plt.xlabel('Age of victim')
plt.ylabel('Count')
plt.title('Black police shooting victims age distribution')
# Out:
# Text(0.5, 1.0, 'Black police shooting victims age distribution')

# %%
sns.histplot(white_police_shooting_victims['age'])

plt.xlabel('Age of victim')
plt.ylabel('Count')
plt.title('White police shooting victims age distribution')
# Out:
# Text(0.5, 1.0, 'White police shooting victims age distribution')

# %%
# titanic[titanic["Pclass"].isin([2, 3])]
b_and_w_police_shootings = police_shootings_df[police_shootings_df['race'].isin(['B', 'W'])]
b_and_w_police_shootings[:5]
# Out:
#    id               name        date manner_of_death       armed   age gender  \
# 1   4   Lewis Lee Lembke  2015-01-02            shot         gun  47.0      M
# 3   8    Matthew Hoffman  2015-01-04            shot  toy weapon  32.0      M
# 5  11  Kenneth Joe Brown  2015-01-04            shot         gun  18.0      M
# 7  15      Brock Nichols  2015-01-06            shot         gun  35.0      M
# 8  16      Autumn Steele  2015-01-06            shot     unarmed  34.0      F
#
#   race           city state  signs_of_mental_illness threat_level  \
# 1    W          Aloha    OR                    False       attack
# 3    W  San Francisco    CA                     True       attack
# 5    W        Guthrie    OK                    False       attack
# 7    W        Assaria    KS                    False       attack
# 8    W     Burlington    IA                    False        other
#
#           flee  body_camera
# 1  Not fleeing        False
# 3  Not fleeing        False
# ...

# %%
sns.histplot(data=b_and_w_police_shootings, x=b_and_w_police_shootings['age'], hue=b_and_w_police_shootings['race'], color='red')
plt.xlabel('Age of victim')
plt.ylabel('Count')
plt.title('Black and white police shooting victims age distribution')
# Out:
# Text(0.5, 1.0, 'Black and white police shooting victims age distribution')

# %%
sns.histplot(data=black_police_shooting_victims, x=black_police_shooting_victims['age'], color='red')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
b_and_w_police_shootings[:3]
# Out:
#    id               name        date manner_of_death       armed   age gender  \
# 1   4   Lewis Lee Lembke  2015-01-02            shot         gun  47.0      M
# 3   8    Matthew Hoffman  2015-01-04            shot  toy weapon  32.0      M
# 5  11  Kenneth Joe Brown  2015-01-04            shot         gun  18.0      M
#
#   race           city state  signs_of_mental_illness threat_level  \
# 1    W          Aloha    OR                    False       attack
# 3    W  San Francisco    CA                     True       attack
# 5    W        Guthrie    OK                    False       attack
#
#           flee  body_camera
# 1  Not fleeing        False
# 3  Not fleeing        False
# 5  Not fleeing        False

# %%
b_and_w_police_shootings['threat_level'].value_counts()
# Out:
# attack          1591
# other            749
# undetermined     109
# Name: threat_level, dtype: int64

# %%
sns.barplot(data=black_police_shooting_victims, x=black_police_shooting_victims['threat_level'].unique(), y=black_police_shooting_victims['threat_level'].value_counts())
# Out:
# <AxesSubplot:ylabel='threat_level'>

# %%
sns.barplot(data=white_police_shooting_victims, x=white_police_shooting_victims['threat_level'].unique(), y=white_police_shooting_victims['threat_level'].value_counts())
# Out:
# <AxesSubplot:ylabel='threat_level'>

# %%
b_and_w_police_shootings[:3]
# Out:
#    id               name        date manner_of_death       armed   age gender  \
# 1   4   Lewis Lee Lembke  2015-01-02            shot         gun  47.0      M
# 3   8    Matthew Hoffman  2015-01-04            shot  toy weapon  32.0      M
# 5  11  Kenneth Joe Brown  2015-01-04            shot         gun  18.0      M
#
#   race           city state  signs_of_mental_illness threat_level  \
# 1    W          Aloha    OR                    False       attack
# 3    W  San Francisco    CA                     True       attack
# 5    W        Guthrie    OK                    False       attack
#
#           flee  body_camera
# 1  Not fleeing        False
# 3  Not fleeing        False
# 5  Not fleeing        False

# %%
b_and_w_police_shootings[b_and_w_police_shootings['gender'].isin(['F'])][:4]
# Out:
#      id                name        date   manner_of_death    armed   age  \
# 8    16       Autumn Steele  2015-01-06              shot  unarmed  34.0
# 51  100  Kristiana Coignard  2015-01-22  shot and Tasered    knife  17.0
# 67  111       Tiffany Terry  2015-01-27              shot    knife  39.0
# 80  118   Yuvette Henderson  2015-02-03              shot      gun  38.0
#
#    gender race        city state  signs_of_mental_illness threat_level  \
# 8       F    W  Burlington    IA                    False        other
# 51      F    W    Longview    TX                     True        other
# 67      F    W       Omaha    NE                     True       attack
# 80      F    B  Emeryville    CA                    False       attack
#
#            flee  body_camera
# 8   Not fleeing         True
# 51  Not fleeing        False
# 67  Not fleeing        False
# 80          Car        False

# %%
b_and_w_police_shootings[b_and_w_police_shootings['armed'].isin(['unarmed'])][:4]
# Out:
#      id                 name        date manner_of_death    armed   age  \
# 8    16        Autumn Steele  2015-01-06            shot  unarmed  34.0
# 17   36  Artago Damon Howard  2015-01-08            shot  unarmed  36.0
# 71  342         Ralph Willis  2015-01-29            shot  unarmed  42.0
# 77  114        David Kassick  2015-02-02            shot  unarmed  59.0
#
#    gender race         city state  signs_of_mental_illness threat_level  \
# 8       F    W   Burlington    IA                    False        other
# 17      M    B       Strong    AR                    False       attack
# 71      M    W   Stillwater    OK                    False        other
# 77      M    W  Hummelstown    PA                    False        other
#
#            flee  body_camera
# 8   Not fleeing         True
# 17  Not fleeing        False
# 71         Foot        False
# 77         Foot        False

# %%
b_and_w_police_shootings.corr()
# Out:
#                                id       age  signs_of_mental_illness  \
# id                       1.000000  0.021690                -0.048258
# age                      0.021690  1.000000                 0.090397
# signs_of_mental_illness -0.048258  0.090397                 1.000000
# body_camera              0.014474 -0.017853                 0.014567
#
#                          body_camera
# id                          0.014474
# age                        -0.017853
# signs_of_mental_illness     0.014567
# body_camera                 1.000000

# %%
b_and_w_new_york_shootings = b_and_w_police_shootings[b_and_w_police_shootings['state'].isin(['NY'])]
b_and_w_new_york_shootings[:5]
# Out:
#       id             name        date   manner_of_death         armed   age  \
# 95   133  Vincent Cordaro  2015-02-08              shot           gun  57.0
# 214  309      James Ellis  2015-03-21              shot           gun  44.0
# 220  234     Denzel Brown  2015-03-22  shot and Tasered  undetermined  21.0
# 301  395  Jonathan Efraim  2015-04-22              shot           gun  30.0
# 312  411      David Felix  2015-04-25              shot       unarmed  24.0
#
#     gender race       city state  signs_of_mental_illness threat_level  \
# 95       M    W   New City    NY                     True       attack
# 214      M    W  Clarendon    NY                    False       attack
# 220      M    B      Islip    NY                    False       attack
# 301      M    W     Queens    NY                     True       attack
# 312      M    B   New York    NY                     True       attack
#
#             flee  body_camera
# 95   Not fleeing        False
# ...

# %%
len(b_and_w_new_york_shootings)
# Out:
# 49

# %%
new_york_police_shootings = police_shootings_df[police_shootings_df['state'].isin(['NY'])]
new_york_police_shootings[:5]
# Out:
#       id             name        date   manner_of_death         armed   age  \
# 95   133  Vincent Cordaro  2015-02-08              shot           gun  57.0
# 214  309      James Ellis  2015-03-21              shot           gun  44.0
# 220  234     Denzel Brown  2015-03-22  shot and Tasered  undetermined  21.0
# 301  395  Jonathan Efraim  2015-04-22              shot           gun  30.0
# 312  411      David Felix  2015-04-25              shot       unarmed  24.0
#
#     gender race       city state  signs_of_mental_illness threat_level  \
# 95       M    W   New City    NY                     True       attack
# 214      M    W  Clarendon    NY                    False       attack
# 220      M    B      Islip    NY                    False       attack
# 301      M    W     Queens    NY                     True       attack
# 312      M    B   New York    NY                     True       attack
#
#             flee  body_camera
# 95   Not fleeing        False
# ...

# %%
len(new_york_police_shootings)
# Out:
# 59

# %%
california_police_shootings = police_shootings_df[police_shootings_df['state'].isin(['CA'])]
california_police_shootings[:5]
# Out:
#     id             name        date   manner_of_death       armed   age  \
# 3    8  Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 10  19   Patrick Wetter  2015-01-06  shot and Tasered       knife  25.0
# 22  43   Brian  Barbosa  2015-01-11              shot         gun  23.0
# 35  63        Jose Ceja  2015-01-15              shot       knife  36.0
# 38  68    Zaki Shinwary  2015-01-16  shot and Tasered       knife  48.0
#
#    gender race           city state  signs_of_mental_illness threat_level  \
# 3       M    W  San Francisco    CA                     True       attack
# 10      M    W       Stockton    CA                    False       attack
# 22      M    H     South Gate    CA                    False       attack
# 35      M    H      Fairfield    CA                     True        other
# 38      M    O        Fremont    CA                    False        other
#
#            flee  body_camera
# 3   Not fleeing        False
# ...

# %%
len(california_police_shootings)
# Out:
# 545

# %%
new_york_police_shootings['city'].unique()
# Out:
# array(['New City', 'Clarendon', 'Islip', 'Queens', 'New York', 'Beacon',
#        'Constantia', 'Greece', 'Bronx', 'Coney Island', 'Malone',
#        'Edinburg', 'Staten Island', 'Troy', 'Mount Vernon', 'Potsdam',
#        'New Paltz', 'Yonkers', 'Syracuse', 'Cheektowaga', 'Rochester',
#        'Rotterdam', 'Berne', 'Schenectady', 'Middletown', 'Brooklyn',
#        'Buffalo', 'Glenville', 'Canandaigua', 'Horseheads', 'Tremont',
#        'Elmira', 'Manhasset', 'Pembroke', 'Merrick', 'Warwick'],
#       dtype=object)

# %%
plt.figure(figsize=(30, 5))
sns.barplot(x=new_york_police_shootings['city'].unique()[:13], y=new_york_police_shootings['city'].value_counts()[:13])
# Out:
# <AxesSubplot:ylabel='city'>

# %%
plt.figure(figsize=(30, 5))
sns.barplot(x=california_police_shootings['city'].unique()[:13], y=california_police_shootings['city'].value_counts()[:13])
# Out:
# <AxesSubplot:ylabel='city'>

# %%
police_shootings_df['race'].unique()
# Out:
# array(['A', 'W', 'H', 'B', 'O', nan, 'N'], dtype=object)
